# %%
import pylizard, matplotlib.pyplot as plt, pastas
# %matplotlib inline

# %%
code, filt = '16FL0041', 1
p = pylizard.Peilbuis(code, filt)

# %% [markdown]
# Collect the monitored head and KNMI data

# %%
ho = p.head_total()
knmi_stn = pastas.read.KnmiStation(stns=273, start='1995',  interval='daily')
knmi_stn.download()

rain = knmi_stn.data['RH']
evap = knmi_stn.data['EV24']

# %% [markdown]
# Plot observed head and stresses

# %%
fig, ax = plt.subplots(2, figsize=[16,9], sharex=True)
ho.plot(ax=ax[0])
rain.plot(ax=ax[1])
evap.plot(ax=ax[1])

# %% [markdown]
# Create a Pastas-model for the observed head with two stress-models for rain en evaporation and solve

# %%
ml = pastas.Model(ho)
sm1 = pastas.StressModel(rain, pastas.Gamma, name='rain', settings='prec')
sm2 = pastas.StressModel(evap, pastas.Gamma, name='evap', settings='evap', up=False)
ml.add_stressmodel(sm1)
ml.add_stressmodel(sm2)
ml.solve(tmin='2003')
# Out:
# c:\python36\lib\site-packages\pastas\stressmodels.py:297: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   h = h.loc[tindex]
# Model Results combi                Fit Statistics
# ============================    ============================
# nfev     33                     EVP                    76.97
# nobs     5328                   NS                      0.77
# noise    NoiseModel             Pearson R2              0.88
# tmin     2003-01-01 01:00:00    RMSE                    0.18
# tmax     2018-04-04 01:00:00    AIC                    14.35
# freq     D                      BIC                    67.00
# warmup   3650                   __
# solver   LeastSquares           ___
#
# Parameters (8 were optimized)
# ============================================================
#                 optimal                  stderr     initial vary
# rain_A       580.240729   ± 3.35029e+01 (5.77%)  447.474566    1
# rain_n         1.610035   ± 1.78132e-02 (1.11%)    1.000000    1
# rain_a        67.042855   ± 3.34280e+00 (4.99%)   10.000000    1
# evap_A      -581.927600   ± 5.50278e+01 (9.46%) -622.265648    1
# evap_n         2.459448  ± 3.09241e-01 (12.57%)    1.000000    1
# evap_a        47.449347  ± 8.14655e+00 (17.17%)   10.000000    1
# constant_d     8.177470   ± 1.06418e-01 (1.30%)    8.582616    1
# noise_alpha   85.131295  ± 1.04767e+01 (12.31%)   14.000000    1
#
# Warnings
# ============================================================
# [1] Parameter values of ['evap_a'] are close to their minimum values.
# [2] Parameter values of ['evap_A'] are close to their maximum values.

# %% [markdown]
# Plot the results of the timiseries-model

# %%
ml.plot(tmin='1995',figsize=(16, 8))
plt.show()
# Out:
# c:\python36\lib\site-packages\pastas\stressmodels.py:297: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   h = h.loc[tindex]

# %% [markdown]
# Plot the response of rain and evaporation

# %%
block_rain = ml.get_block_response('rain')
block_evap = ml.get_block_response('evap')
cutoff_rain = sm1.rfunc.cutoff
cutoff_evap = sm2.rfunc.cutoff
tmax_rain = sm1.rfunc.tmax
tmax_evap = sm2.rfunc.tmax

fig, ax = plt.subplots(figsize=[16, 9])
block_rain.plot(ax=ax)
block_evap.plot(ax=ax)
plt.axhline(0, color='k', linestyle='-')

plt.xlabel('time (days)')
plt.ylabel('response to unit impulse (m)')

plt.title('Rain {} cutoff is {} days\n'.format(cutoff_rain, round(tmax_rain))+'Evap {} cutoff is {} days'.format(cutoff_evap, round(tmax_evap)));
